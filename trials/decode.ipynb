# %% [markdown]
# - 2025년 9월 9일(화)

# %%
import base64
import json

# 예시 Base64 문자열 (로그에서 발췌한 AUTHN_INFO 값 일부)
b64_string = "..."

# 1. Base64 디코딩
decoded_bytes = base64.b64decode(b64_string)

# 2. JSON 문자열 변환
decoded_str = decoded_bytes.decode("utf-8")

# 3. JSON 파싱
try:
    data = json.loads(decoded_str)
    print("디코딩된 JSON:", data)
except json.JSONDecodeError:
    print("JSON으로 파싱 불가. 원문 출력:")
    print(decoded_str)
# Out:
# 디코딩된 JSON: {'xtm': '2025-08-21T00:01:35.103', 'xid': 'IDP-16b46ee3233fd83562100d32db60b228', 'idpsession': 'CB262B99FD01605D7F11D162CA5BD99D', 'token': '[USER]\nPW_CHANGE_WARN=7\nNOT_AFTER=20250821100135\nNOW_LOGIN_IP=127.0.0.1\nSESSION_TIME=10\nNOW_LOGIN_TIME=20250821090135\nNAME=홍길동\nPW_VALIDATE=90\nPOLLING_TIME=30\nLOGIN_TYPE=ID_PW\nLAST_LOGIN_TIME=20250821090113\nPW_MISMATCH_ALLOW=5\nPW_UPDATE_DAYS=0\nTIMESTAMP=20250821090135059\nLAST_LOGIN_IP=127.0.0.1\nID=ssouser\n\n[APPLDEFAULT]'}

# %%
data_path = "/home/kongju/DEV/dream/DATA/LOGS/sp2__ssoagent_20250821.log"

# %%
import re
import base64
import json
import pandas as pd

def extract_authn_info_from_log(filepath: str):
    """
    로그 파일에서 AUTHN_INFO Base64 문자열을 추출하고 디코딩 → JSON 파싱까지 수행
    """
    with open(filepath, "r", encoding="utf-8", errors="ignore") as f:
        content = f.read()

    # AUTHN_INFO 블록 찾기 (AttributeValue 안의 Base64 문자열 캡처)
    matches = re.findall(
        r'<saml2:Attribute Name="AUTHN_INFO">.*?<saml2:AttributeValue.*?>(.*?)</saml2:AttributeValue>',
        content,
        re.DOTALL
    )

    results = []
    for idx, b64_str in enumerate(matches, 1):
        try:
            decoded_str = base64.b64decode(b64_str).decode("utf-8", errors="ignore")
            parsed_json = json.loads(decoded_str)
        except Exception as e:
            parsed_json = {"error": str(e), "raw_decoded": decoded_str}

        results.append({"index": idx, "base64": b64_str.strip(), "parsed": parsed_json})

    return results


def flatten_authn_info(parsed_json: dict):
    """
    AUTHN_INFO JSON에서 token 내부의 Key=Value를 추출해 DataFrame으로 반환
    """
    top = {k: v for k, v in parsed_json.items() if k != "token"}
    token_text = parsed_json.get("token", "")
    kv = {}
    in_user = False
    for line in token_text.splitlines():
        line = line.strip()
        if not line:
            if in_user:
                break
            continue
        if line.startswith("[") and line.endswith("]"):
            section = line.strip("[]").upper()
            if section == "USER":
                in_user = True
                continue
            elif in_user:
                break
            continue
        if in_user and "=" in line:
            k, v = line.split("=", 1)
            kv[k.strip()] = v.strip()

    rows = [{"scope": "top", "key": k, "value": v} for k, v in top.items()]
    rows += [{"scope": "token.USER", "key": k, "value": v} for k, v in kv.items()]
    return pd.DataFrame(rows, columns=["scope", "key", "value"])

# %%
log_file = "/home/kongju/DEV/dream/DATA/LOGS/sp2__ssoagent_20250821.log"

# AUTHN_INFO 추출
results = extract_authn_info_from_log(log_file)

for r in results:
    print(f"\n=== AUTHN_INFO #{r['index']} ===")
    print("Base64 snippet:", r["base64"][:80], "...")
    if isinstance(r["parsed"], dict) and "token" in r["parsed"]:
        df = flatten_authn_info(r["parsed"])
        print(df)
    else:
        print("Parsing 실패:", r["parsed"])
# Out:
# === AUTHN_INFO #1 ===
# Base64 snippet: eyJ4dG0iOiIyMDI1LTA4LTIxVDA1OjI0OjU4LjkwOSIsInhpZCI6IklEUC1hNWY4MWIwMzRmMzFjZGUz ...
#          scope                key                                 value
# 0          top                xtm               2025-08-21T05:24:58.909
# 1          top                xid  IDP-a5f81b034f31cde385fdd91cec985bec
# 2          top         idpsession      7CA150B783D3829CB734219083500681
# 3   token.USER     PW_CHANGE_WARN                                     7
# 4   token.USER          NOT_AFTER                        20250821152436
# 5   token.USER       NOW_LOGIN_IP                             127.0.0.1
# 6   token.USER       SESSION_TIME                                    10
# 7   token.USER     NOW_LOGIN_TIME                        20250821142436
# 8   token.USER               NAME                                   홍길동
# 9   token.USER        PW_VALIDATE                                    90
# 10  token.USER       POLLING_TIME                                    30
# 11  token.USER         LOGIN_TYPE                                 ID_PW
# 12  token.USER    LAST_LOGIN_TIME                        20241209110350
# 13  token.USER  PW_MISMATCH_ALLOW                                     5
# 14  token.USER     PW_UPDATE_DAYS                                   269
# 15  token.USER          TIMESTAMP                     20250821142436885
# 16  token.USER      LAST_LOGIN_IP                             127.0.0.1
# 17  token.USER                 ID                               ssouser
#
# === AUTHN_INFO #2 ===
# Base64 snippet: eyJ4dG0iOiIyMDI1LTA4LTIxVDA1OjI1OjE5Ljc3NyIsInhpZCI6IklEUC0yY2VmYTQ4MTRlMTc4ODc5 ...
#          scope                key                                 value
# 0          top                xtm               2025-08-21T05:25:19.777
# 1          top                xid  IDP-2cefa4814e178879b8ce934ec2def536
# 2          top         idpsession      E7952781CD9E3CFC0F1EFA95BFE97B7D
# 3   token.USER     PW_CHANGE_WARN                                     7
# 4   token.USER          NOT_AFTER                        20250821152519
# 5   token.USER       NOW_LOGIN_IP                             127.0.0.1
# 6   token.USER       SESSION_TIME                                    10
# 7   token.USER     NOW_LOGIN_TIME                        20250821142519
# 8   token.USER               NAME                                   홍길동
# 9   token.USER        PW_VALIDATE                                    90
# 10  token.USER       POLLING_TIME                                    30
# 11  token.USER         LOGIN_TYPE                                 ID_PW
# 12  token.USER    LAST_LOGIN_TIME                        20250821142436
# 13  token.USER  PW_MISMATCH_ALLOW                                     5
# 14  token.USER     PW_UPDATE_DAYS                                   269
# 15  token.USER          TIMESTAMP                     20250821142519715
# 16  token.USER      LAST_LOGIN_IP                             127.0.0.1
# 17  token.USER                 ID                               ssouser
#
# === AUTHN_INFO #3 ===
# Base64 snippet: eyJ4dG0iOiIyMDI1LTA4LTIxVDA1OjMwOjI5LjUzMyIsInhpZCI6IklEUC01YjRiNjU3MGQzYzA5MTg4 ...
#          scope                key                                 value
# 0          top                xtm               2025-08-21T05:30:29.533
# 1          top                xid  IDP-5b4b6570d3c091889173be4108d42a36
# 2          top         idpsession      EC405618A18E1B1208E0BF7B1FDD4B40
# 3   token.USER     PW_CHANGE_WARN                                     7
# 4   token.USER          NOT_AFTER                        20250821153018
# 5   token.USER       NOW_LOGIN_IP                             127.0.0.1
# 6   token.USER       SESSION_TIME                                    10
# 7   token.USER     NOW_LOGIN_TIME                        20250821143018
# 8   token.USER               NAME                                   홍길동
# 9   token.USER        PW_VALIDATE                                    90
# 10  token.USER       POLLING_TIME                                    30
# 11  token.USER         LOGIN_TYPE                                 ID_PW
# 12  token.USER    LAST_LOGIN_TIME                        20250821142519
# 13  token.USER  PW_MISMATCH_ALLOW                                     5
# 14  token.USER     PW_UPDATE_DAYS                                   269
# 15  token.USER          TIMESTAMP                     20250821143018430
# 16  token.USER      LAST_LOGIN_IP                             127.0.0.1
# 17  token.USER                 ID                               ssouser
#
# === AUTHN_INFO #4 ===
# Base64 snippet: eyJ4dG0iOiIyMDI1LTA4LTIxVDA1OjMwOjUyLjMyMSIsInhpZCI6IklEUC03YTk3MjQ4NWNkOWU0ZWI3 ...
#          scope                key                                 value
# 0          top                xtm               2025-08-21T05:30:52.321
# 1          top                xid  IDP-7a972485cd9e4eb779483bf229f5aaeb
# 2          top         idpsession      19D066C88FF822450AE96722AAECBA5D
# 3   token.USER     PW_CHANGE_WARN                                     7
# 4   token.USER          NOT_AFTER                        20250821153052
# 5   token.USER       NOW_LOGIN_IP                             127.0.0.1
# 6   token.USER       SESSION_TIME                                    10
# 7   token.USER     NOW_LOGIN_TIME                        20250821143052
# 8   token.USER               NAME                                   홍길동
# 9   token.USER        PW_VALIDATE                                    90
# 10  token.USER       POLLING_TIME                                    30
# 11  token.USER         LOGIN_TYPE                                 ID_PW
# 12  token.USER    LAST_LOGIN_TIME                        20250821143018
# 13  token.USER  PW_MISMATCH_ALLOW                                     5
# 14  token.USER     PW_UPDATE_DAYS                                   269
# 15  token.USER          TIMESTAMP                     20250821143052128
# 16  token.USER      LAST_LOGIN_IP                             127.0.0.1
# 17  token.USER                 ID                               ssouser
#
# === AUTHN_INFO #5 ===
# Base64 snippet: eyJ4dG0iOiIyMDI1LTA4LTIxVDA1OjQ0OjE4LjQxMiIsInhpZCI6IklEUC0zZmZiZGI4NGQ2NTBhODlm ...
#          scope                key                                 value
# 0          top                xtm               2025-08-21T05:44:18.412
# 1          top                xid  IDP-3ffbdb84d650a89fc72fa71ce8e5edfb
# 2          top         idpsession      E607C222B83569557EBDB8B671B169CA
# 3   token.USER     PW_CHANGE_WARN                                     7
# 4   token.USER          NOT_AFTER                        20250821154123
# 5   token.USER       NOW_LOGIN_IP                             127.0.0.1
# 6   token.USER       SESSION_TIME                                    10
# 7   token.USER     NOW_LOGIN_TIME                        20250821144123
# 8   token.USER               NAME                                   홍길동
# 9   token.USER        PW_VALIDATE                                    90
# 10  token.USER       POLLING_TIME                                    30
# 11  token.USER         LOGIN_TYPE                                 ID_PW
# 12  token.USER    LAST_LOGIN_TIME                        20250821143759
# 13  token.USER  PW_MISMATCH_ALLOW                                     5
# 14  token.USER     PW_UPDATE_DAYS                                   269
# 15  token.USER          TIMESTAMP                     20250821144123391
# 16  token.USER      LAST_LOGIN_IP                             127.0.0.1
# 17  token.USER                 ID                               ssouser
#
# === AUTHN_INFO #6 ===
# Base64 snippet: eyJ4dG0iOiIyMDI1LTA4LTIxVDA2OjIyOjA0LjQ2MiIsInhpZCI6IklEUC1jNjYyY2IzNmEwYmIxYTBj ...
#          scope                key                                 value
# 0          top                xtm               2025-08-21T06:22:04.462
# 1          top                xid  IDP-c662cb36a0bb1a0cea7362440bb4588d
# 2          top         idpsession      52B0B0FD34ADC09F5F62F6832ABE0389
# 3   token.USER     PW_CHANGE_WARN                                     7
# 4   token.USER          NOT_AFTER                        20250821162159
# 5   token.USER       NOW_LOGIN_IP                             127.0.0.1
# 6   token.USER       SESSION_TIME                                    10
# 7   token.USER     NOW_LOGIN_TIME                        20250821152159
# 8   token.USER               NAME                                   홍길동
# 9   token.USER        PW_VALIDATE                                    90
# 10  token.USER       POLLING_TIME                                    30
# 11  token.USER         LOGIN_TYPE                                 ID_PW
# 12  token.USER    LAST_LOGIN_TIME                        20250821152131
# 13  token.USER  PW_MISMATCH_ALLOW                                     5
# 14  token.USER     PW_UPDATE_DAYS                                   269
# 15  token.USER          TIMESTAMP                     20250821152159640
# 16  token.USER      LAST_LOGIN_IP                             127.0.0.1
# 17  token.USER                 ID                               ssouser
#
# === AUTHN_INFO #7 ===
# Base64 snippet: eyJ4dG0iOiIyMDI1LTA4LTIxVDA2OjMxOjU0LjAwOSIsInhpZCI6IklEUC1iMjFhNWE0MDQ5ODRiYWYw ...
#          scope                key                                 value
# 0          top                xtm               2025-08-21T06:31:54.009
# 1          top                xid  IDP-b21a5a404984baf0c952d4adc6316275
# 2          top         idpsession      7ADC397A5F3052CA3677584C1D6F4C38
# 3   token.USER     PW_CHANGE_WARN                                     7
# 4   token.USER          NOT_AFTER                        20250821163153
# 5   token.USER       NOW_LOGIN_IP                             127.0.0.1
# 6   token.USER       SESSION_TIME                                    10
# 7   token.USER     NOW_LOGIN_TIME                        20250821153153
# 8   token.USER               NAME                                   홍길동
# 9   token.USER        PW_VALIDATE                                    90
# 10  token.USER       POLLING_TIME                                    30
# 11  token.USER         LOGIN_TYPE                                 ID_PW
# 12  token.USER    LAST_LOGIN_TIME                        20250821153104
# 13  token.USER  PW_MISMATCH_ALLOW                                     5
# 14  token.USER     PW_UPDATE_DAYS                                   269
# 15  token.USER          TIMESTAMP                     20250821153153974
# 16  token.USER      LAST_LOGIN_IP                             127.0.0.1
# 17  token.USER                 ID                               ssouser

# %%
df.to_excel("sp2__ssoagent_20250821_authn_info.xlsx")
